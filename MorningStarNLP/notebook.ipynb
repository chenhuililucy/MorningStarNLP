# %%
import pandas as pd
import torch
from datasets import Dataset
from transformers import DistilBertTokenizerFast, DistilBertConfig
from sklearn.model_selection import train_test_split

# Load dataset
df = pd.read_csv("morningstar_equity_research.csv")

# Ensure content is not null
df = df.dropna(subset=["content"])
df = df.drop_duplicates(subset=["content"])

# %%
df
# Out:
#                                                   title  \
# 0     Going Into Earnings, is NatWest Group a Buy, S...
# 1     The UK’s Most-Shorted Stocks: Consumer Names T...
# 2     After Earnings, Is Alphabet Stock a Buy, a Sel...
# 3     After Earnings, Is Palantir Stock a Buy, a Sel...
# 4     These 19 US Dividend Aristocrats Provide Attra...
# ...                                                 ...
# 8425                         T Clarke upbeat on outlook
# 8426                         Pendragon bids for Lookers
# 8427                   British Airways holds down costs
# 8428                       ITV's picture looks brighter
# 8429                               Travis looking Perky
#
#                                                     url  \
# 0     https://www.morningstar.co.uk/uk/news/260807/g...
# 1     https://www.morningstar.co.uk/uk/news/260801/t...
# 2     https://www.morningstar.co.uk/uk/news/260789/a...
# 3     https://www.morningstar.co.uk/uk/news/260785/a...
# ...

# %%
import sys
sys.path.append("clean")  # Add the 'clean' directory to the Python path

from textCleaning import textCleaning

# %%
processor = textCleaning(num_merges=1000, top_n=5, similarity_threshold=0.95)
df["content"] = df["content"].apply(processor.clean)
df["content"] = processor.process_documents(df["content"])
# Out:
# [nltk_data] Downloading package punkt to /Users/lichenhui/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/lichenhui/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 🔍 Extracting most frequent merged phrases...
